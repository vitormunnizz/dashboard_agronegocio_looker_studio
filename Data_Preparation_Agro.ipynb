# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
# Montando o Google Drive no ambiente do Google Colab
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Definindo os caminhos dos arquivos CSV de exportação e importação
file_path = '/content/drive/MyDrive/projeto_dnc/df_exp_tratado.xlsx'

# %%
df = pd.read_excel(file_path)

# %%
# Removendo valores ausentes e duplicados
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  CO_ANO  CO_MES    CO_NCM  CO_PAIS SG_UF_NCM  KG_LIQUIDO  \
# 0           0    2024       8  64039990      301        CE         989
# 1           1    2024       8  24012030       87        SC      462000
# 2           2    2024      10  33011290      249        SP     2067847
# 3           3    2024       1  41044130      858        GO       27469
# 4           4    2024      10  62171000      580        SP          20
#
#      VL_FOB                                          Categoria  \
# 0     25361                     Calçados e artigos de calçados
# 1   4236540            Tabaco e seus substitutos manufaturados
# 2  29292037  Óleos Essenciais, perfumaria, cosmética, higie...
# 3    320819                                     Couros e peles
# 4        75                Vestuário e Acessórios de Vestuário
#
#                                              Produto              Tipo  \
# 0                                 Partes de Calçados          Calçados
# 1          Tabaco não manufaturado; restos de tabaco            Tabaco
# 2  Óleos; essenciais (concretos, absolutos); seus...  Óleos Essenciais
# 3  Couros e peles curtidos ou em crosta de bovino...             Couro
# 4                                             Roupas            Roupas
#
#     Origem        Setor
# 0  Vegetal  Agricultura
# 1   Tabaco  Agricultura
# 2  Vegetal  Agricultura
# 3  Bovinos     Pecuária
# 4  Vegetal  Agricultura

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423632 entries, 0 to 423631
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  423632 non-null  int64
#  1   CO_ANO      423632 non-null  int64
#  2   CO_MES      423632 non-null  int64
#  3   CO_NCM      423632 non-null  int64
#  4   CO_PAIS     423632 non-null  int64
#  5   SG_UF_NCM   423632 non-null  object
#  6   KG_LIQUIDO  423632 non-null  int64
#  7   VL_FOB      423632 non-null  int64
#  8   Categoria   423632 non-null  object
#  9   Produto     423632 non-null  object
#  10  Tipo        423632 non-null  object
#  11  Origem      423632 non-null  object
#  12  Setor       423632 non-null  object
# dtypes: int64(7), object(6)
# memory usage: 42.0+ MB

# %%
# Selecionando apenas as colunas relevantes para análise de exportação e importação
df = df[['CO_NCM', 'Origem', 'CO_ANO', 'VL_FOB']]

# %%
# Agrupando os dados de exportação por NCM somando os valores FOB
df_exp = df.groupby(['CO_NCM', 'Origem', 'CO_ANO'], as_index=False)['VL_FOB'].sum()

# %%
df_exp.head()
# Out:
#      CO_NCM   Origem  CO_ANO     VL_FOB
# 0  10011100    Trigo    2024      26417
# 1  10011900    Trigo    2024         31
# 2  10019100    Trigo    2024      26136
# 3  10019900    Trigo    2024  608108402
# 4  10029000  Centeio    2024      13433

# %%
df_exp_2023 = pd.read_csv('/content/drive/MyDrive/projeto_dnc/EXP_2023.csv', sep=';')

# %%
df_exp_2023.head()
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA   CO_URF  \
# 0    2023       3  84139190       10      160        RJ       4   817700
# 1    2023      12  73182100       10      764        SP       1   817800
# 2    2023       4  84219999       10       40        RS       4   817600
# 3    2023       5  85291090       10       63        RJ       7  1017503
# 4    2023      10  84825010       11       63        MG       7  1017503
#
#    QT_ESTAT  KG_LIQUIDO  VL_FOB
# 0    107365           5      20
# 1         0           0      84
# 2         2           2     758
# 3         1           1     275
# 4         2           0       9

# %%
df_exp_2024 = df_exp.copy()

# %%
df_exp_2024.head()
# Out:
#      CO_NCM   Origem  CO_ANO     VL_FOB
# 0  10011100    Trigo    2024      26417
# 1  10011900    Trigo    2024         31
# 2  10019100    Trigo    2024      26136
# 3  10019900    Trigo    2024  608108402
# 4  10029000  Centeio    2024      13433

# %%
# Selecionando apenas as colunas relevantes para análise de exportação e importação
df_exp_2023 = df_exp_2023[['CO_NCM', 'CO_ANO', 'VL_FOB']].reset_index(drop=True)

# %%
df_exp_2023.head()
# Out:
#      CO_NCM  CO_ANO  VL_FOB
# 0  84139190    2023      20
# 1  73182100    2023      84
# 2  84219999    2023     758
# 3  85291090    2023     275
# 4  84825010    2023       9

# %%
# Fazendo merge com base na coluna CO_NCM
df_exp_2023 = df_exp_2023.merge(
    df_exp[['CO_NCM', 'Origem']],
    on='CO_NCM',
    how='left'
)

# %%
df_exp_2023.head()
# Out:
#      CO_NCM  CO_ANO  VL_FOB Origem
# 0  84139190    2023      20    NaN
# 1  73182100    2023      84    NaN
# 2  84219999    2023     758    NaN
# 3  85291090    2023     275    NaN
# 4  84825010    2023       9    NaN

# %%
df_exp_2023 = df_exp_2023.dropna().reset_index(drop=True)

# %%
df_exp_2023.rename(columns={'VL_FOB': 'VL_FOB_2023'}, inplace=True)
df_exp_2024.rename(columns={'VL_FOB': 'VL_FOB_2024'}, inplace=True)

# %%
# Agrupando os dados de exportação por NCM somando os valores FOB
df_exp_2024 = df_exp_2024.groupby(['Origem'], as_index=False)['VL_FOB_2024'].sum()
df_exp_2023 = df_exp_2023.groupby(['Origem'], as_index=False)['VL_FOB_2023'].sum()

# %%
label_dict = {
    'Soja': 1,
    'Cana de Açúcar': 2,
    'Madeira': 3,
    'Milho': 4,
    'Algodão': 5,
    'Tabaco': 6,
    'Vegetal': 7,
    'Animal': 8,
    'Trigo': 9,
    'Bovinos': 10,
    'Amendoim': 11,
    'Oleaginosas': 12,
    'Vegetal e Animal': 13,
    'Cacau': 14,
    'Arroz': 15,
    'Malte': 16,
    'Leveduras': 17,
    'Plantas ': 18,
    'Sorgo': 19,
    'Amido': 20,
    'Colza': 21,
    'Peixe': 22,
    'Cereais': 23,
    'Mandioca': 24,
    'Animais': 25,
    'Palma': 26,
    'Uva': 27,
    'Aveia': 28,
    'Aves': 29,
    'Centeio': 30,
    'Azeitona': 31,
    'Lã': 32,
    'Tomate': 33,
    'Girassol': 34,
    'Cevada': 35,
    'Madeira': 36
}

# %%
# Aplica a codificação
df_exp_2023['Origem_codificada'] = df_exp_2023['Origem'].map(label_dict)
df_exp_2024['Origem_codificada'] = df_exp_2024['Origem'].map(label_dict)

# %%
df_exp_2023.head()
# Out:
#      Origem  VL_FOB_2023  Origem_codificada
# 0   Algodão   3205148214                  5
# 1  Amendoim    625359219                 11
# 2     Amido     64605374                 20
# 3   Animais     22472696                 25
# 4    Animal   2349734035                  8

# %%
df_exp_2024.head()
# Out:
#      Origem  VL_FOB_2024  Origem_codificada
# 0   Algodão   5289442446                  5
# 1  Amendoim    467769469                 11
# 2     Amido     62198479                 20
# 3   Animais     18510994                 25
# 4    Animal   2249960225                  8

# %%
# Converter a coluna para int (truncando)
df_exp_2024['Origem_codificada'] = df_exp_2024['Origem_codificada'].astype(int)
df_exp_2023['Origem_codificada'] = df_exp_2023['Origem_codificada'].astype(int)

# %%
# Calculando o valor total geral
total_exp_2024 = df_exp_2024['VL_FOB_2024'].sum()

# Criando uma nova coluna com a participação percentual de cada produto
df_exp_2024['PERC_PARTICIPACAO_EXP'] = ((df_exp_2024['VL_FOB_2024'] / total_exp_2024) * 100).round(2)

# Ordenando do maior para o menor
df_exp_2024 = df_exp_2024.sort_values(by='PERC_PARTICIPACAO_EXP', ascending=False)

# %%
# Calculando o valor total geral
total_exp_2023 = df_exp_2023['VL_FOB_2023'].sum()

# Criando uma nova coluna com a participação percentual de cada produto
df_exp_2023['PERC_PARTICIPACAO_EXP'] = ((df_exp_2023['VL_FOB_2023'] / total_exp_2023) * 100).round(2)

# Ordenando do maior para o menor
df_exp_2023 = df_exp_2023.sort_values(by='PERC_PARTICIPACAO_EXP', ascending=False)

# %%
df_exp_2024
# Out:
#               Origem  VL_FOB_2024  Origem_codificada  PERC_PARTICIPACAO_EXP
# 27              Soja  54140037484                  1                  42.76
# 11    Cana de Açúcar  20222626420                  2                  15.97
# 19           Madeira  16803729821                 36                  13.27
# 33           Vegetal   9691882998                  7                   7.65
# 22             Milho   8177075971                  4                   6.46
# 0            Algodão   5289442446                  5                   4.18
# 29            Tabaco   2975322951                  6                   2.35
# 4             Animal   2249960225                  8                   1.78
# 34  Vegetal e Animal   1773548798                 13                   1.40
# 9            Bovinos   1236311850                 10                   0.98
# 26          Plantas     634333632                 18                   0.50
# 10             Cacau    635632956                 14                   0.50
# 31             Trigo    610096077                  9                   0.48
# 5              Arroz    561165277                 15                   0.44
# 1           Amendoim    467769469                 11                   0.37
# 23       Oleaginosas    472168555                 12                   0.37
# 20             Malte    201196016                 16                   0.16
# 17         Leveduras    205718330                 17                   0.16
# 2              Amido     62198479                 20                   0.05
# 25             Peixe     32150866                 22                   0.03
# 13           Cereais     33537141                 23                   0.03
# 28             Sorgo     41347270                 19                   0.03
# 15             Colza     30304808                 21                   0.02
# 24             Palma     13652480                 26                   0.01
# 21          Mandioca      8750852                 24                   0.01
# 32               Uva     12811595                 27                   0.01
# 3            Animais     18510994                 25                   0.01
# 18                Lã      3936925                 32                   0.00
# 16          Girassol        92060                 34                   0.00
# 12           Centeio        13433                 30                   0.00
# 14            Cevada          973                 35                   0.00
# 8           Azeitona      1390464                 31                   0.00
# 6              Aveia       929981                 28                   0.00
# 7               Aves          619                 29                   0.00
# 30            Tomate      3322768                 33                   0.00

# %%
df_exp_2024 = df_exp_2024.merge(
    df_exp_2023[['Origem_codificada', 'VL_FOB_2023']],
    on='Origem_codificada',
    how='left'
)

# %%
df_exp_2024
# Out:
#               Origem  VL_FOB_2024  Origem_codificada  PERC_PARTICIPACAO_EXP  \
# 0               Soja  54140037484                  1                  42.76
# 1     Cana de Açúcar  20222626420                  2                  15.97
# 2            Madeira  16803729821                 36                  13.27
# 3            Vegetal   9691882998                  7                   7.65
# 4              Milho   8177075971                  4                   6.46
# 5            Algodão   5289442446                  5                   4.18
# 6             Tabaco   2975322951                  6                   2.35
# 7             Animal   2249960225                  8                   1.78
# 8   Vegetal e Animal   1773548798                 13                   1.40
# 9            Bovinos   1236311850                 10                   0.98
# 10          Plantas     634333632                 18                   0.50
# 11             Cacau    635632956                 14                   0.50
# 12             Trigo    610096077                  9                   0.48
# 13             Arroz    561165277                 15                   0.44
# 14          Amendoim    467769469                 11                   0.37
# 15       Oleaginosas    472168555                 12                   0.37
# 16             Malte    201196016                 16                   0.16
# 17         Leveduras    205718330                 17                   0.16
# 18             Amido     62198479                 20                   0.05
# 19             Peixe     32150866                 22                   0.03
# 20           Cereais     33537141                 23                   0.03
# 21             Sorgo     41347270                 19                   0.03
# 22             Colza     30304808                 21                   0.02
# 23             Palma     13652480                 26                   0.01
# 24          Mandioca      8750852                 24                   0.01
# 25               Uva     12811595                 27                   0.01
# 26           Animais     18510994                 25                   0.01
# 27                Lã      3936925                 32                   0.00
# 28          Girassol        92060                 34                   0.00
# 29           Centeio        13433                 30                   0.00
# 30            Cevada          973                 35                   0.00
# 31          Azeitona      1390464                 31                   0.00
# 32             Aveia       929981                 28                   0.00
# 33              Aves          619                 29                   0.00
# 34            Tomate      3322768                 33                   0.00
#
#     VL_FOB_2023
# 0   67509187644
# 1   17909021749
# 2   13819639007
# 3    8752182375
# 4   13613016930
# 5    3205148214
# 6    2729473808
# 7    2349734035
# 8    1612794358
# 9    1095717218
# 10    580173964
# 11    372974153
# 12    732642833
# 13    621462879
# 14    625359219
# 15    320457729
# 16    154175894
# 17    166160411
# 18     64605374
# 19     31059345
# 20     32448593
# 21      8372410
# 22      7824636
# 23     17566203
# 24      6562053
# 25     12976668
# 26     22472696
# 27      3223899
# 28        51343
# 29        11022
# 30          975
# 31       787916
# 32      3552872
# 33          232
# 34      3092419

# %%
# 3. Calcular a diferença
df_exp_2024['DIF_VL_FOB'] = df_exp_2024['VL_FOB_2024'] - df_exp_2024['VL_FOB_2023']

# %%
df_exp_2024['PERC_DIF_VL_FOB'] = ((df_exp_2024['DIF_VL_FOB'] / df_exp_2024['VL_FOB_2023']) * 100).round(2)

# %%
df_exp_2024
# Out:
#               Origem  VL_FOB_2024  Origem_codificada  PERC_PARTICIPACAO_EXP  \
# 0               Soja  54140037484                  1                  42.76
# 1     Cana de Açúcar  20222626420                  2                  15.97
# 2            Madeira  16803729821                 36                  13.27
# 3            Vegetal   9691882998                  7                   7.65
# 4              Milho   8177075971                  4                   6.46
# 5            Algodão   5289442446                  5                   4.18
# 6             Tabaco   2975322951                  6                   2.35
# 7             Animal   2249960225                  8                   1.78
# 8   Vegetal e Animal   1773548798                 13                   1.40
# 9            Bovinos   1236311850                 10                   0.98
# 10          Plantas     634333632                 18                   0.50
# 11             Cacau    635632956                 14                   0.50
# 12             Trigo    610096077                  9                   0.48
# 13             Arroz    561165277                 15                   0.44
# 14          Amendoim    467769469                 11                   0.37
# 15       Oleaginosas    472168555                 12                   0.37
# 16             Malte    201196016                 16                   0.16
# 17         Leveduras    205718330                 17                   0.16
# 18             Amido     62198479                 20                   0.05
# 19             Peixe     32150866                 22                   0.03
# 20           Cereais     33537141                 23                   0.03
# 21             Sorgo     41347270                 19                   0.03
# 22             Colza     30304808                 21                   0.02
# 23             Palma     13652480                 26                   0.01
# 24          Mandioca      8750852                 24                   0.01
# 25               Uva     12811595                 27                   0.01
# 26           Animais     18510994                 25                   0.01
# 27                Lã      3936925                 32                   0.00
# 28          Girassol        92060                 34                   0.00
# 29           Centeio        13433                 30                   0.00
# 30            Cevada          973                 35                   0.00
# 31          Azeitona      1390464                 31                   0.00
# 32             Aveia       929981                 28                   0.00
# 33              Aves          619                 29                   0.00
# 34            Tomate      3322768                 33                   0.00
#
#     VL_FOB_2023   DIF_VL_FOB  PERC_DIF_VL_FOB
# 0   67509187644 -13369150160           -19.80
# 1   17909021749   2313604671            12.92
# 2   13819639007   2984090814            21.59
# 3    8752182375    939700623            10.74
# 4   13613016930  -5435940959           -39.93
# 5    3205148214   2084294232            65.03
# 6    2729473808    245849143             9.01
# 7    2349734035    -99773810            -4.25
# 8    1612794358    160754440             9.97
# 9    1095717218    140594632            12.83
# 10    580173964     54159668             9.34
# 11    372974153    262658803            70.42
# 12    732642833   -122546756           -16.73
# 13    621462879    -60297602            -9.70
# 14    625359219   -157589750           -25.20
# 15    320457729    151710826            47.34
# 16    154175894     47020122            30.50
# 17    166160411     39557919            23.81
# 18     64605374     -2406895            -3.73
# 19     31059345      1091521             3.51
# 20     32448593      1088548             3.35
# 21      8372410     32974860           393.85
# 22      7824636     22480172           287.30
# 23     17566203     -3913723           -22.28
# 24      6562053      2188799            33.36
# 25     12976668      -165073            -1.27
# 26     22472696     -3961702           -17.63
# 27      3223899       713026            22.12
# 28        51343        40717            79.30
# 29        11022         2411            21.87
# 30          975           -2            -0.21
# 31       787916       602548            76.47
# 32      3552872     -2622891           -73.82
# 33          232          387           166.81
# 34      3092419       230349             7.45

# %%
df_exp_2024.to_csv('df_exp_2024.csv')
